# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sss = pd.read_csv('SuperStoreSales.csv')

# %%
sss.describe()
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
sss.head(10)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156   8/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156   8/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688   12/6/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 5       6  CA-2015-115812    9/6/2015  14/06/2015  Standard Class    BH-11710
# 6       7  CA-2015-115812    9/6/2015  14/06/2015  Standard Class    BH-11710
# 7       8  CA-2015-115812    9/6/2015  14/06/2015  Standard Class    BH-11710
# 8       9  CA-2015-115812    9/6/2015  14/06/2015  Standard Class    BH-11710
# 9      10  CA-2015-115812    9/6/2015  14/06/2015  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City       State  \
# ...

# %%
sss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
sss.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='object')

# %%
sss.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
(sss.isnull().mean()*100).sort_values(ascending=False)
# Out:
# Postal Code      0.112245
# Row ID           0.000000
# Order ID         0.000000
# Order Date       0.000000
# Ship Mode        0.000000
# Ship Date        0.000000
# Customer Name    0.000000
# Segment          0.000000
# Country          0.000000
# Customer ID      0.000000
# City             0.000000
# State            0.000000
# Region           0.000000
# Product ID       0.000000
# Category         0.000000
# Sub-Category     0.000000
# Product Name     0.000000
# Sales            0.000000
# dtype: float64

# %%
sss.duplicated().sum()
# Out:
# np.int64(0)

# %%
#remove spaces, convert all columns names into lowercase, replace space with underscore.
#This makes columns work easily
sss.columns = sss.columns.str.strip().str.lower().str.replace(" ","_")

# %%
sss.columns
# Out:
# Index(['row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'country', 'city', 'state',
#        'postal_code', 'region', 'product_id', 'category', 'sub-category',
#        'product_name', 'sales'],
#       dtype='object')

# %%
sss['category'].value_counts()
# Out:
# category
# Office Supplies    5909
# Furniture          2078
# Technology         1813
# Name: count, dtype: int64

# %%
sss.describe()
# Out:
#             row_id   postal_code         sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
sss['order_date']
# Out:
# 0        8/11/2017
# 1        8/11/2017
# 2        12/6/2017
# 3       11/10/2016
# 4       11/10/2016
#            ...
# 9795    21/05/2017
# 9796     12/1/2016
# 9797     12/1/2016
# 9798     12/1/2016
# 9799     12/1/2016
# Name: order_date, Length: 9800, dtype: object

# %%
sss['order_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
sss['order_date'] = pd.to_datetime(sss['order_date'], format = '%d/%m/%Y', errors='coerce')

# %%
sss['order_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
sss['order_date'].head(10)
# Out:
# 0   2017-11-08
# 1   2017-11-08
# 2   2017-06-12
# 3   2016-10-11
# 4   2016-10-11
# 5   2015-06-09
# 6   2015-06-09
# 7   2015-06-09
# 8   2015-06-09
# 9   2015-06-09
# Name: order_date, dtype: datetime64[ns]

# %%
sss['ship_date'] = pd.to_datetime(sss['ship_date'], format = '%d/%m/%Y', errors='coerce')

# %%
sss['ship_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
sss['order_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
sss['order_date'].head(5)
# Out:
# 0   2017-11-08
# 1   2017-11-08
# 2   2017-06-12
# 3   2016-10-11
# 4   2016-10-11
# Name: order_date, dtype: datetime64[ns]

# %%
sss['ship_date'].head(5)
# Out:
# 0   2017-11-11
# 1   2017-11-11
# 2   2017-06-16
# 3   2016-10-18
# 4   2016-10-18
# Name: ship_date, dtype: datetime64[ns]

# %%
sss.info
# Out:
# <bound method DataFrame.info of       row_id        order_id order_date  ship_date       ship_mode  \
# 0          1  CA-2017-152156 2017-11-08 2017-11-11    Second Class
# 1          2  CA-2017-152156 2017-11-08 2017-11-11    Second Class
# 2          3  CA-2017-138688 2017-06-12 2017-06-16    Second Class
# 3          4  US-2016-108966 2016-10-11 2016-10-18  Standard Class
# 4          5  US-2016-108966 2016-10-11 2016-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9795    9796  CA-2017-125920 2017-05-21 2017-05-28  Standard Class
# 9796    9797  CA-2016-128608 2016-01-12 2016-01-17  Standard Class
# 9797    9798  CA-2016-128608 2016-01-12 2016-01-17  Standard Class
# 9798    9799  CA-2016-128608 2016-01-12 2016-01-17  Standard Class
# 9799    9800  CA-2016-128608 2016-01-12 2016-01-17  Standard Class
#
#      customer_id     customer_name    segment        country             city  \
# ...

# %%
sss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   row_id         9800 non-null   int64
#  1   order_id       9800 non-null   object
#  2   order_date     9800 non-null   datetime64[ns]
#  3   ship_date      9800 non-null   datetime64[ns]
#  4   ship_mode      9800 non-null   object
#  5   customer_id    9800 non-null   object
#  6   customer_name  9800 non-null   object
#  7   segment        9800 non-null   object
#  8   country        9800 non-null   object
#  9   city           9800 non-null   object
#  10  state          9800 non-null   object
#  11  postal_code    9789 non-null   float64
#  12  region         9800 non-null   object
#  13  product_id     9800 non-null   object
#  14  category       9800 non-null   object
#  15  sub-category   9800 non-null   object
#  16  product_name   9800 non-null   object
# ...

# %%
# This removes the entire row if postal_code is empty
sss.dropna(subset=['postal_code'], inplace=True)

# %%
sss
# Out:
#       row_id        order_id order_date  ship_date       ship_mode  \
# 0          1  CA-2017-152156 2017-11-08 2017-11-11    Second Class
# 1          2  CA-2017-152156 2017-11-08 2017-11-11    Second Class
# 2          3  CA-2017-138688 2017-06-12 2017-06-16    Second Class
# 3          4  US-2016-108966 2016-10-11 2016-10-18  Standard Class
# 4          5  US-2016-108966 2016-10-11 2016-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9795    9796  CA-2017-125920 2017-05-21 2017-05-28  Standard Class
# 9796    9797  CA-2016-128608 2016-01-12 2016-01-17  Standard Class
# 9797    9798  CA-2016-128608 2016-01-12 2016-01-17  Standard Class
# 9798    9799  CA-2016-128608 2016-01-12 2016-01-17  Standard Class
# 9799    9800  CA-2016-128608 2016-01-12 2016-01-17  Standard Class
#
#      customer_id     customer_name    segment        country             city  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
sss['postal_code']=sss['postal_code'].astype(int)

# %%
sss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9789 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   row_id         9789 non-null   int64
#  1   order_id       9789 non-null   object
#  2   order_date     9789 non-null   datetime64[ns]
#  3   ship_date      9789 non-null   datetime64[ns]
#  4   ship_mode      9789 non-null   object
#  5   customer_id    9789 non-null   object
#  6   customer_name  9789 non-null   object
#  7   segment        9789 non-null   object
#  8   country        9789 non-null   object
#  9   city           9789 non-null   object
#  10  state          9789 non-null   object
#  11  postal_code    9789 non-null   int64
#  12  region         9789 non-null   object
#  13  product_id     9789 non-null   object
#  14  category       9789 non-null   object
#  15  sub-category   9789 non-null   object
#  16  product_name   9789 non-null   object
# ...

# %%
sss['city'].isnull().sum()
# Out:
# np.int64(0)

# %%
sss['category'].value_counts().plot(kind="bar")
plt.title("Count by CAtegory")
plt.xlabel("Category")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
sss.groupby("category")["sales"].sum().sort_values(ascending=False).plot(kind="bar")
plt.title("Total Sales by Category")
plt.xlabel("Category")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')
